# %%
#data loaded in the form of pixel data. (0-255 range for colored number)(RGB Data) 3-d

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline

# %%
img_array = mpimg.imread('C:\\Users\\varun\\flag.jpg')
img_array
# Out:
# array([[[252, 255, 255],
#         [255, 247, 250],
#         [255, 240, 239],
#         ...,
#         [255, 234, 221],
#         [255, 233, 215],
#         [255, 245, 230]],
#
#        [[255, 249, 248],
#         [ 96,  48,  46],
#         [115,  40,  35],
#         ...,
#         [187,  75,  53],
#         [174,  95,  78],
#         [255, 243, 229]],
#
#        [[255, 239, 231],
#         [118,  45,  36],
#         [137,  35,  23],
#         ...,
#         [220,  63,  32],
#         [164,  78,  61],
#         [255, 243, 230]],
#
#        ...,
#
#        [[242, 255, 249],
#         [ 14,  45,  30],
#         [  2,  47,  27],
#         ...,
#         [  0,  84,  35],
#         [ 35,  79,  56],
#         [234, 255, 247]],
#
#        [[251, 255, 255],
#         [164, 170, 168],
#         [163, 172, 169],
#         ...,
#         [170, 187, 177],
#         [178, 187, 184],
#         [248, 254, 252]],
#
#        [[251, 255, 255],
#         [246, 252, 250],
#         [249, 255, 255],
# ...

# %%
img_array.shape
# Out:
# (258, 482, 3)

# %%
img_array
# Out:
# array([[[252, 255, 255],
#         [255, 247, 250],
#         [255, 240, 239],
#         ...,
#         [255, 234, 221],
#         [255, 233, 215],
#         [255, 245, 230]],
#
#        [[255, 249, 248],
#         [ 96,  48,  46],
#         [115,  40,  35],
#         ...,
#         [187,  75,  53],
#         [174,  95,  78],
#         [255, 243, 229]],
#
#        [[255, 239, 231],
#         [118,  45,  36],
#         [137,  35,  23],
#         ...,
#         [220,  63,  32],
#         [164,  78,  61],
#         [255, 243, 230]],
#
#        ...,
#
#        [[242, 255, 249],
#         [ 14,  45,  30],
#         [  2,  47,  27],
#         ...,
#         [  0,  84,  35],
#         [ 35,  79,  56],
#         [234, 255, 247]],
#
#        [[251, 255, 255],
#         [164, 170, 168],
#         [163, 172, 169],
#         ...,
#         [170, 187, 177],
#         [178, 187, 184],
#         [248, 254, 252]],
#
#        [[251, 255, 255],
#         [246, 252, 250],
#         [249, 255, 255],
# ...

# %%
img_array[150,0,0:3]
# Out:
# array([244, 255, 255], dtype=uint8)

# %%
bgr = img_array[:,:,(2,1,0)]
plt.imshow(bgr)

# %%
img_2 =img_array[:,:,2]
img_2.shape
# Out:
# (258, 482)

# %%
img_r = np.zeros(img_array.shape, dtype ="uint8")
img_r[:,:,2] = img_2

# %%
plt.imshow(img_r)

# %%
plt.imshow(img_array)
plt.show()

# %%
258*482
#dot points
# Out:
# 124356

# %%
img_array[50,0,0:3] 
#50 height, 0 width , 3 layers of colors
# Out:
# array([255, 245, 236], dtype=uint8)

# %%
#each pixel has 8-32 bits(box)-- 8-2pow 8

# %%
img_array[1,0,0]
# Out:
# 255

# %%
#rgbcolor to grey sacle

# %%
#gray_fun = lambda rgb : np.dot(rgb[..., :3], [0.299, 0.587 , 0.114])
#gray_fun = lambda rgb : np.dot(rgb[..., :3], [0.100, 0.100 , 0.100])
gray_img_array= gray_fun(img_array)
print(gray_img_array.shape)
# Out:
# (258, 482)

# %%
plt.imshow(gray_img_array, cmap = 'gray')
plt.show()
